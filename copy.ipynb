# %%
####################################
#
#
#  ADD THIS TO EVERY COLAB FILE!
#
#
####################################

import sys
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# drive.flush_and_unmount()

PATH_PROJECT = '/content/drive/MyDrive/Mestrado/ime_am_malware/'
PATH_DATA = PATH_PROJECT + 'data/'

sys.path.append(PATH_PROJECT)
#import gdrive.MyDrive.Mestrado.ime_am_malware.package_name
# Out:
# Mounted at /content/drive

# %%
! cp -r --verbose drive/MyDrive/Mestrado/ime_am_malware/.git/ drive/Shareddrives/GPT-J-6B/ime_am_malware/
# Out:
# 'drive/MyDrive/Mestrado/ime_am_malware/data/kaggle/asm/aTfDJBX2PNZRIjUG1SKz.asm' -> 'drive/Shareddrives/GPT-J-6B/ime_am_malware/data/kaggle/asm/aTfDJBX2PNZRIjUG1SKz.asm'
# cp: cannot create regular file 'drive/Shareddrives/GPT-J-6B/ime_am_malware/data/kaggle/asm/aTfDJBX2PNZRIjUG1SKz.asm': No such file or directory
# cp: cannot stat 'drive/MyDrive/Mestrado/ime_am_malware/data/kaggle/asm/c9tj6deKFW4zDfOvE5VG.asm': No such file or directory
# cp: cannot stat 'drive/MyDrive/Mestrado/ime_am_malware/data/kaggle/asm/0pER9ak46CKVjPoqGLcD.asm': No such file or directory
# cp: cannot stat 'drive/MyDrive/Mestrado/ime_am_malware/data/kaggle/asm/3qi6bX9lBAxoCPapGzmR.asm': No such file or directory
# cp: cannot stat 'drive/MyDrive/Mestrado/ime_am_malware/data/kaggle/asm/cpW2HoJgMx70C8ETSfsZ.asm': No such file or directory

# %%
! ls drive/Shareddrives/GPT-J-6B/ime_am_malware/data/kaggle/
