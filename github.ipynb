# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Keys

# %%
# ! ssh-keygen -t ed25519 -C "vanzan2015@gmail.com" # /root/.ssh/id_ed25519

# ! cp /root/.ssh/id_ed25519 /content/drive/Shareddrives/GPTJ/data/
# ! cp /root/.ssh/id_ed25519.pub /content/drive/Shareddrives/GPTJ/data/

! cp /content/drive/Shareddrives/GPTJ/data/id_ed25519 /root/.ssh/
! cp /content/drive/Shareddrives/GPTJ/data/id_ed25519.pub /root/.ssh/

! eval `ssh-agent -s` && ssh-add ~/.ssh/id_ed25519
# ! cat /root/.ssh/id_ed25519.pub
# Out:
# Agent pid 475
# Identity added: /root/.ssh/id_ed25519 (vanzan2015@gmail.com)

# %% [markdown]
# # Github

# %%
PATH = '/content/drive/Shareddrives/GPTJ/project/'

! cd $PATH && git remote -v
! cd $PATH && git status
# Out:
# origin	https://github.com/matheusvanzan/ime-am-malware.git (fetch)
# origin	https://github.com/matheusvanzan/ime-am-malware.git (push)
# On branch master
# Your branch is ahead of 'origin/master' by 5 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
! cd $PATH && git add --all
! cd $PATH && git commit -m "working gpt-2 completion method"
# Out:
# [master 99e661e] working gpt-2 completion method
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite github.ipynb (60%)

# %%
! cd $PATH && git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# git@github.com:matheusvanzan/ime-am-malware.git

! cd $PATH && git remote set-url origin git@github.com:matheusvanzan/ime-am-malware.git
