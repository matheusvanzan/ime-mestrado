# %%
####################################
#
#  ADD THIS TO EVERY COLAB FILE!
#
####################################

#!pip install -q import-ipynb

from google.colab import drive
drive.mount('/content/drive')

#import import_ipynb
import drive.Shareddrives.GPTJ.project.settings as settings

PATH_PROJECT = settings.PATH_PROJECT
PATH_DATA = settings.PATH_DATA

! cd $PATH_PROJECT && pip install -q -r requirements.txt
# Out:
# Mounted at /content/drive
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 143 kB 5.1 MB/s
#      |████████████████████████████████| 55.9 MB 305 kB/s
#      |████████████████████████████████| 717 kB 81.4 MB/s
#      |████████████████████████████████| 7.6 MB 55.8 MB/s
#      |████████████████████████████████| 163 kB 83.7 MB/s
#      |████████████████████████████████| 54 kB 2.5 MB/s
#      |████████████████████████████████| 120 kB 70.2 MB/s
#      |████████████████████████████████| 99 kB 243 kB/s
#   Building wheel for transformers (PEP 517) ... done
#   Building wheel for deepspeed (setup.py) ... done
#   Building wheel for py-cpuinfo (setup.py) ... done

# %%
# !nvidia-smi -L

# Standard -> Tesla T4
# Premium -> Tesla P100-PCIE-16GB
# Out:
# GPU 0: Tesla T4 (UUID: GPU-684f6c66-d082-23c1-16ed-8ca799e22e93)

# %%
! cd $PATH_PROJECT && time python main.py
# Out:
# =================
# Using model: gpt2
# Will train? False
# =================
# Using saved tokenizer...
# Using saved model...
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 0: Four women have been arrested in connection with the attack, which left at least seven dead and more than 100 injured.  The attack comes as the government is facing criticism for failing to tackle the problem of sexual violence in the country.  The
# 1: Four women have been arrested in connection with the attack, which left at least seven dead and more than 100 injured.  The attack comes as the government is facing criticism for failing to tackle the problem of sexual violence in the country.  The
# 2: Four women have been arrested in connection with the attack, which left at least seven dead and more than 100 injured.  The attack comes as the government is facing criticism for failing to tackle the problem of sexual violence in the country.  The
# -----------------
# Four women
# -----------------
#  have been arrested in connection with the attack, which left at least seven dead and more than 100 injured.  The attack comes as the government is facing criticism for failing to tackle the problem of sexual violence in the country.  The
# -----------------
# =================
# Using model: gpt2
# Will train? True
# =================
# Using saved tokenizer...
# Using saved model...
# max_length 42
# len(dataset) 10
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 8
#   Num Epochs = 5
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 20
# 100% 20/20 [00:13<00:00,  1.45it/s]
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 13.7826, 'train_samples_per_second': 2.902, 'train_steps_per_second': 1.451, 'train_loss': 4.543120956420898, 'epoch': 5.0}
# 100% 20/20 [00:13<00:00,  1.45it/s]
# {'train_runtime': 13.7826, 'train_samples_per_second': 2.902, 'train_steps_per_second': 1.451, 'train_loss': 4.543120956420898, 'epoch': 5.0}
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 0: Four women
# 1: Four women
# 2: Four women
# -----------------
# Four women
# -----------------
#
# -----------------
#
# real	0m29.686s
# user	0m25.729s
# sys	0m3.267s

# %%
! cd $PATH_DATA && ls "kaggle/asm/" | wc -l
! cd $PATH_DATA && ls "kaggle/proc-1/all/" | wc -l
# Out:
# 10868
# 10868
