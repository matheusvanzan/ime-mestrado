# %%
! which python
! pwd
# Out:
# /c/Users/vanza/Documents/Codes/ime/am-malware/project/env/Scripts/python
# /c/Users/vanza/Documents/Codes/ime/am-malware/project

# %% [markdown]
# # Treino

# %%
! python main.py --train --multi --model='gpt2' --limit='1024' --epochs='1' --batch='16' --fold='1'
! python main.py --test  --multi --model='gpt2' --limit='1024' --epochs='1' --batch='16' --fold='1'

! python main.py --train --multi --model='gpt2' --limit='1024' --epochs='1' --batch='160' --fold='1'
! python main.py --test  --multi --model='gpt2' --limit='1024' --epochs='1' --batch='160' --fold='1'

# %%
! python main.py --train --multi --model='gpt2-medium' --limit='1024' --epochs='1' --batch='16' --fold='1'
! python main.py --test  --multi --model='gpt2-medium' --limit='1024' --epochs='1' --batch='16' --fold='1'

! python main.py --train --multi --model='gpt2-medium' --limit='1024' --epochs='1' --batch='160' --fold='1'
! python main.py --test  --multi --model='gpt2-medium' --limit='1024' --epochs='1' --batch='160' --fold='1'

# %%
# ! python main.py --train --multi --model='gpt2-large' --limit='1024' --epochs='1' --batch='16' --fold='1'
! python main.py --test  --multi --model="gpt2-large" --limit=1024 --epochs=1 --batch=16 --fold=1

# ! python main.py --train --multi --model='gpt2-large' --limit='1024' --epochs='1' --batch='160' --fold='1'
# ! python main.py --test  --multi --model='gpt2-large' --limit='1024' --epochs='1' --batch='160' --fold='1'
# Out:
# ^C
# ...
#  34%|███▍      | 1469/4308 [01:43<04:16, 11.07it/s]
# Namespace(process=False, complete=False, train=False, check=False, test=True, metrics=False, cache=False, multi=True, model='gpt2-large', limit='1024', epochs='1', batch='16', label=None, fold='1', path=None)
# pid: 24668
# Args: limit 1024
# Args: epochs 1
# Args: batch 16
# Args: labels ['all']
# Args: path C:\Users\vanza\Documents\Codes\ime\am-malware\data\kaggle\proc-1
# Args: model_name gpt2-large
# Args: multi True
# Args: fold 1
# Model: name gpt2-large
# Model: label 'all'
# Model: num_labels 9
# Model: using saved tokenizer...
# -----
# label 0
# -----
# label 1
# -----
# label 2
# -----
# label 3
# -----
# label 4
# -----
# label 5
# -----
# label 6
# -----
# label 7
# -----
# label 8
# Dataset: label 0 - test - in model as torch.tensor(0)
# Dataset: label 0 - test - loading from C:\Users\vanza\Documents\Codes\ime\am-malware\data\kaggle\proc-1\0.limit-1024.fold-1.chunk-32.test.csv ...
# ...

# %% [markdown]
# # Metrics

# %%
# ! cd $PATH_PROJECT && python main.py --metrics --multi --model='gpt2' --limit='1024' --epochs='1' --batch='160' --fold='1'
