# %%
import pickle

path = '/home/jovyan/data/tfidf/g1_ms1_mf20_f1_X_test.pkl'

with open(path, 'rb') as f:
    df = pickle.load(f)

df
# Out:
#                            loc       mov      push       sub      text
# 12TEseaJ4jnbyORqKxhf  0.134578  0.279706  0.015040  0.112196  0.943843
# 1mStzMaQ8RUVBx7TkF4o  0.147684  0.263779  0.018252  0.126185  0.944645
# 2bdnyMU3XQlIA5grPeZm  0.117535  0.142850  0.119343  0.091315  0.971184
# 2RsBPMStVQNc7x3kgYde  0.147530  0.127149  0.165543  0.121609  0.959101
# 3bapyeGYC5Zot4Sm1NOd  0.171840  0.143255  0.090684  0.156069  0.957793
# ...                        ...       ...       ...       ...       ...
# jASo6C54kaZUxit0egTL  0.052479  0.003414  0.046207  0.058116  0.995852
# JBGVawO7uqtxM103PbNy  0.118647  0.205179  0.100891  0.139910  0.956071
# jF8Qxdo3MyVEc9l6O2B1  0.117784  0.188454  0.110243  0.130496  0.959911
# JM34WTehCb9VuiQEgr7K  0.101047  0.215537  0.194721  0.145503  0.940344
# k6Mnj2POrsKEqVxeNJAu  0.112251  0.226459  0.104649  0.153116  0.949589
#
# [788 rows x 5 columns]

# %%
path = '/home/jovyan/data/tfidf/g1_ms1_mf50_f1_X_test.pkl'

with open(path, 'rb') as f:
    df = pickle.load(f)

df
# Out:
#                             00        01        04        08        10  \
# 12TEseaJ4jnbyORqKxhf  0.253951  0.034279  0.031012  0.019729  0.022504
# 1mStzMaQ8RUVBx7TkF4o  0.240703  0.022454  0.036983  0.021833  0.017015
# 2bdnyMU3XQlIA5grPeZm  0.256019  0.018873  0.015591  0.026258  0.100930
# 2RsBPMStVQNc7x3kgYde  0.288390  0.029234  0.029008  0.020516  0.017773
# 3bapyeGYC5Zot4Sm1NOd  0.207132  0.023099  0.029786  0.029330  0.078264
# ...                        ...       ...       ...       ...       ...
# jASo6C54kaZUxit0egTL  0.799685  0.041838  0.042585  0.039025  0.018409
# JBGVawO7uqtxM103PbNy  0.382838  0.008502  0.016102  0.007980  0.018239
# jF8Qxdo3MyVEc9l6O2B1  0.474345  0.013534  0.007876  0.013826  0.012018
# JM34WTehCb9VuiQEgr7K  0.357526  0.006226  0.007783  0.006287  0.015322
# k6Mnj2POrsKEqVxeNJAu  0.380880  0.006930  0.009693  0.007706  0.019046
#
#                             15        24        40        41        44  ...  \
# ...
